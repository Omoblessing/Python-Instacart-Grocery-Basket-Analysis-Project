# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing orders.csv

# %%
df_ords = pd.read_csv(r'C:\Users\49157\Downloads\Instacart Basket Analysis\02 Data\Original Data\4.3_orders_products\orders.csv', index_col = False)

# %%
# Importing products.csv

# %%
df_prods = pd.read_csv(r'C:\Users\49157\Downloads\Instacart Basket Analysis\02 Data\Original Data\4.3_orders_products\products.csv', index_col = False)

# %%
# Variety list (step 2) Find another identifier variable in the df_ords data frame that doesn’t need to be included in your analysis as a numeric variable and change it to a suitable format.

# %%
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
vars_list
# Out:
# ['order_id',
#  'user_id',
#  'order_number',
#  'order_dow',
#  'order_hour_of_day',
#  'days_since_prior_order']

# %%
df_ords.head(50)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# ...

# %%
# Dropping days_since_prior_order from the orders.csv

# %%
df_ords.drop(columns = ['days_since_prior_order'])
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day
# 0                        8
# 1                        7
# 2                       12
# 3                        7
# 4                       15
# ...                    ...
# 3421078                 18
# ...

# %%
# convert days_since_prior_order to a string

# %%
df_ords['days_since_prior_order'] = df_ords['days_since_prior_order'].astype('str')

# %%
df_ords['days_since_prior_order'].dtype
# Out:
# dtype('O')

# %%
# Step 3 - Look for a variable in your df_ords data frame with an unintuitive name and change its name without overwriting the dataframe.

# %%
df_ords.rename(columns = {'eval_set' : 'evaluation_set'}, inplace = True)

# %%
df_ords.head()
# Out:
#    order_id  user_id evaluation_set  order_number  order_dow  \
# 0   2539329        1          prior             1          2
# 1   2398795        1          prior             2          3
# 2    473747        1          prior             3          3
# 3   2254736        1          prior             4          4
# 4    431534        1          prior             5          4
#
#    order_hour_of_day days_since_prior_order
# 0                  8                    nan
# 1                  7                   15.0
# 2                 12                   21.0
# 3                  7                   29.0
# 4                 15                   28.0

# %%
# Step 4: Your client wants to know what the busiest hour is for placing orders. Find the frequency of the corresponding variable and share your findings.

# %%
print(df_ords.order_hour_of_day)
# Out:
# 0           8
# 1           7
# 2          12
# 3           7
# 4          15
#            ..
# 3421078    18
# 3421079    10
# 3421080    12
# 3421081    12
# 3421082    14
# Name: order_hour_of_day, Length: 3421083, dtype: int64

# %%
print(df_ords.columns)

# %%
# calculating frequency

# %%
order_hour_frequency = df_ords['order_hour_of_day'].value_counts().sort_index()

# %%
print (order_hour_frequency)
# Out:
# order_hour_of_day
# 0      22758
# 1      12398
# 2       7539
# 3       5474
# 4       5527
# 5       9569
# 6      30529
# 7      91868
# 8     178201
# 9     257812
# 10    288418
# 11    284728
# 12    272841
# 13    277999
# 14    283042
# 15    283639
# 16    272553
# 17    228795
# 18    182912
# 19    140569
# 20    104292
# 21     78109
# 22     61468
# 23     40043
# Name: count, dtype: int64

# %%
# To identify the busiest hour

# %%
busiest_hour = order_hour_frequency.idxmax()

# %%
print (busiest_hour)
# Out:
# 10

# %%
maximum_orders = order_hour_frequency.max()

# %%
print (maximum_orders)
# Out:
# 288418

# %%
# Step 5 -- Determine the meaning behind a value of 4 in the "department_id" column within the df_prods data frame using a data dictionary.

# %%
# Importing data set department.csv

# %%
df_dep = pd.read_csv(r'C:\Users\49157\Downloads\Instacart Basket Analysis\02 Data\Original Data\4.4_departments\departments.csv', index_col = False)

# %%
path = r'C:\Users\49157\Downloads\Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\49157\\Downloads\\Instacart Basket Analysis'

# %%
# The meaning of department_id 4

# %%
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t = df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
data_dict = df_dep_t.to_dict('index')

# %%
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
print(df_prods.head())
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
# Step 6-- The sales team in your client’s organization wants to know more about breakfast item sales. Create a subset containing only the required information.

# %%
breakfast_items = df_prods[df_prods['department_id'] == 14]

# %%
print(breakfast_items)
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
# Step 7-- They’d also like to see details about products that customers might use to throw dinner parties. Your task is to find all observations from the entire data frame that include items from the following departments: alcohol, deli, beverages, and meat/seafood. You’ll need to present this subset to your client.

# %%
Dinner_parties = df_prods[df_prods['department_id']. isin([5,7,12,20])]

# %%
print (Dinner_parties)
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
 Dinner_parties = df_prods.loc[df_prods['department_id']. isin([5,7,12,20])]

# %%
 Dinner_parties
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
# Step 8--It’s important that you keep track of total counts in your dataframes. How many rows does the last dataframe you created have

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
df_prods.shape
# Out:
# (49693, 5)

# %%
df_dep.shape
# Out:
# (1, 22)

# %%
# Step 9--Someone from the data engineers team in Instacart thinks they’ve spotted something strange about the customer with a "user_id" of “1.” Extract all the information you can about this user.

# %%
customer = df_ords[df_ords['user_id'] == 1]

# %%
print(customer)
# Out:
#     order_id  user_id evaluation_set  order_number  order_dow  \
# 0    2539329        1          prior             1          2
# 1    2398795        1          prior             2          3
# 2     473747        1          prior             3          3
# 3    2254736        1          prior             4          4
# 4     431534        1          prior             5          4
# 5    3367565        1          prior             6          2
# 6     550135        1          prior             7          1
# 7    3108588        1          prior             8          1
# 8    2295261        1          prior             9          1
# 9    2550362        1          prior            10          4
# 10   1187899        1          train            11          4
#
#     order_hour_of_day days_since_prior_order
# 0                   8                    nan
# 1                   7                   15.0
# 2                  12                   21.0
# ...

# %%
# Step 10--You also need to provide some details about this user’s behavior. What basic stats can you provide based on the information you have?

# %% [markdown]
# Here are basic statistics I can derive about this user behavior
# ---The day of the week the user made the order
# ---The hour of the day the order was made
# ---The user's order number

# %%
# Step 12-- Export your df_ords dataframe as “orders_wrangled.csv” in your “Prepared Data” folder.

# %%
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %%
# Step 13-- Export the df_dep_t_new data frame as “departments_wrangled.csv” in your “Prepared Data” folder so that you have a “.csv” file of your departments data in the correct format.

# %%
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'dep_wrangled.csv'))
